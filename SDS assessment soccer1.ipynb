# %% [markdown]
# ## SDS Assessment : Soccer

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
from bs4 import BeautifulSoup

import requests

header = {'User-agent' : 'Mozilla/5.0 (Windows; U; Windows NT 5.1; de; rv:1.9.1.5) Gecko/20091102 Firefox/3.5.5'}

url = requests.get("https://iuhoosiers.com/sports/mens-soccer/stats/2020-21/marshall/boxscore/24459", headers=header).text

soup = BeautifulSoup(url, 'html.parser')
table = soup.find('table', {'class': 'play-by-play'})

df = pd.read_html(str(table))[0]

# %%
df
# Out:
#     Clock                              MU - Play Description  \
# 0   00:00                                                NaN
# 1   00:00              Semmle, Oliver at goalie for Marshall
# 2   01:48                                                NaN
# 3   02:38                         Foul on Dossantos, Nathan.
# 4   04:30                            Foul on Alves, Gabriel.
# 5   07:45                            Shot by MU Dias, Vitor.
# 6   08:43               Shot by MU Schneider, Max, out left.
# 7   13:33                         Shot by MU Roberts, Jamil.
# 8   14:24                                                NaN
# 9   16:20                                                NaN
# 10  17:05  Shot by MU Yosef, Milo, bottom center, saved b...
# 11  17:37                                                NaN
# 12  19:12                            Foul on Alves, Gabriel.
# 13  19:12                  Yellow card on MU Alves, Gabriel.
# ...

# %% [markdown]
# ## Marshall Corner Kicks & Shots

# %%
df.dtypes
# Out:
# Clock                     object
# MU - Play Description     object
# Visiting Team Score      float64
# Team Logo                float64
# Home Team Score          float64
# IU - Play Description     object
# Score                    float64
# Team Indicator           float64
# Play                      object
# dtype: object

# %%
df['MU - Play Description'].str.count("Corner").sum()
# Out:
# 4.0

# %%
df2 = df[df['MU - Play Description'].str.contains("Corner",na=False)]
df2
# Out:
#     Clock MU - Play Description  Visiting Team Score  Team Logo  \
# 17  22:39  Corner kick [22:39].                  NaN        NaN
# 21  30:36  Corner kick [30:36].                  NaN        NaN
# 24  35:30  Corner kick [35:30].                  NaN        NaN
# 31  44:37  Corner kick [44:37].                  NaN        NaN
#
#     Home Team Score IU - Play Description  Score  Team Indicator  \
# 17              NaN                   NaN    NaN             NaN
# 21              NaN                   NaN    NaN             NaN
# 24              NaN                   NaN    NaN             NaN
# 31              NaN                   NaN    NaN             NaN
#
#                     Play
# 17  Corner kick [22:39].
# 21  Corner kick [30:36].
# 24  Corner kick [35:30].
# 31  Corner kick [44:37].

# %% [markdown]
# ## Marshall Corners: 0 from 0-15 min, 1 from 15 - 30 min, 2 from 30-45 min

# %%
df['MU - Play Description'].str.count("Shot").sum()
# Out:
# 8.0

# %%
df2 = df[df['MU - Play Description'].str.contains("Shot",na=False)]
df2
# Out:
#     Clock                              MU - Play Description  \
# 5   07:45                            Shot by MU Dias, Vitor.
# 6   08:43               Shot by MU Schneider, Max, out left.
# 7   13:33                         Shot by MU Roberts, Jamil.
# 10  17:05  Shot by MU Yosef, Milo, bottom center, saved b...
# 16  22:31  Shot by MU Fernandes, Vinicius, bottom right, ...
# 18  24:51  Shot by MU Dias, Vitor, bottom left, saved by ...
# 22  31:21             Shot by MU Yosef, Milo, out top right.
# 25  36:09  Shot by MU Dias, Vitor, bottom center, saved b...
#
#     Visiting Team Score  Team Logo  Home Team Score IU - Play Description  \
# 5                   NaN        NaN              NaN                   NaN
# 6                   NaN        NaN              NaN                   NaN
# 7                   NaN        NaN              NaN                   NaN
# 10                  NaN        NaN              NaN                   NaN
# ...

# %% [markdown]
# ## Marshall Shots: 3 from 0-15 min, 2 from 15 - 30 min, 2 from 30-45 min
